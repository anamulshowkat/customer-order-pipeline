# %%
# PIPELINE CONFIGURATION

# Database & Environment Settings
CATALOG_NAME = "workspace"   # Set to "hive_metastore" if Unity Catalog is not enabled
SCHEMA_NAME = "my_database"  # Define the target database/schema name

# Raw File Paths 
# Update these paths to where your raw files are actually stored (Volumes or DBFS)
RAW_CUSTOMER_PATH = "/Workspace/Users/anaamfaisal@gmail.com/customer-order-pipeline/volumes/customers raw.csv"
RAW_ORDERS_PATH = "/Workspace/Users/anaamfaisal@gmail.com/customer-order-pipeline/volumes/orders raw.csv"

# Customer Pipeline Table Names (01 to 03)
BRONZE_CUSTOMER_TBL = f"{CATALOG_NAME}.{SCHEMA_NAME}.pipeline_table_bronze_customers"
SILVER_CUSTOMER_TBL = f"{CATALOG_NAME}.{SCHEMA_NAME}.pipeline_table_silver_customers"
GOLD_CUSTOMER_TBL = f"{CATALOG_NAME}.{SCHEMA_NAME}.pipeline_table_gold_customers"

# Orders Pipeline Table Names (04 to 06)
BRONZE_ORDERS_TBL = f"{CATALOG_NAME}.{SCHEMA_NAME}.pipeline_table_bronze_orders"
SILVER_ORDERS_TBL = f"{CATALOG_NAME}.{SCHEMA_NAME}.pipeline_table_silver_orders"
GOLD_ORDERS_TBL = f"{CATALOG_NAME}.{SCHEMA_NAME}.pipeline_table_gold_orders"

# Master Data Integration Table Names (join_and view)
MASTER_TABLE_NAME = f"{CATALOG_NAME}.{SCHEMA_NAME}.pipeline_table_customers_orders_master"
MASTER_VIEW_NAME = f"{CATALOG_NAME}.{SCHEMA_NAME}.pipeline_table_vw_customers_orders_master"

# audit log
AUDIT_LOG_TBL = f"{CATALOG_NAME}.{SCHEMA_NAME}.pipeline_audit_log"

print("Pipeline configurations loaded successfully!")

# Verify the table names and paths
print("--- Checking Pipeline Configurations ---")
print(f"Target Catalog: {CATALOG_NAME}")
print(f"Target Schema: {SCHEMA_NAME}")
print(f"Bronze Customer Table: {BRONZE_CUSTOMER_TBL}")
print(f"Master View: {MASTER_VIEW_NAME}")
