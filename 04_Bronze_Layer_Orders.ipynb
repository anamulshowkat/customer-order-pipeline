# %%
# Define the file path for the raw orders data
file_path_orders = "/Workspace/Users/anaamfaisal@gmail.com/customer-order-pipeline/volumes/orders raw.csv"

# Read the CSV file as-is for the Bronze layer
df_orders_bronze = spark.read.format("csv") \
    .option("header", "true") \
    .option("inferSchema", "true") \
    .load(file_path_orders)
# Save the raw data into the Bronze table
df_orders_bronze.write.format("delta") \
    .mode("overwrite") \
    .saveAsTable("workspace.my_database.orders_bronze")

print("Orders Bronze Layer loaded successfully!")
display(df_orders_bronze)
#
